# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# After executing the cell above, Drive
# files will be present in "/content/drive/My Drive".
# !ls "/content/drive/My Drive"
# Out:
#  a-disciplinas-unb		       Evarius.png
#  artigos-trabs-dados-resumos	       foo2.txt
#  bancas-pareceres-admin-autorizacoes   foo.txt
#  bibliografia			      'Fujifilm Customs Films.gsheet'
#  c-arquivos			       open-camera-2020-12
#  cervejas			       ornithapp-S-20-00282.pdf
# 'Colab Notebooks'		       photos
#  c-software			       Screencastify
#  datacolab

# %% [markdown]
# You can also use the file browser in the sidebar to browse Drive files.
# ![](https://i.stack.imgur.com/TxnUX.png)

# %%
# %load_ext rpy2.ipython
# Out:
# /usr/local/lib/python3.6/dist-packages/rpy2/robjects/pandas2ri.py:14: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import Index as PandasIndex
# /usr/local/lib/python3.6/dist-packages/rpy2/robjects/pandas2ri.py:34: UserWarning: pandas >= 1.0 is not supported.
#   warnings.warn('pandas >= 1.0 is not supported.')

# %%
# %%R
# url = ('/content/drive/MyDrive/datacolab/griseoteste.csv')
# dataset = read.csv(url)

# %%
# %%R
# head(dataset)
# Out:
#   longitude    latitude
# 1 -70.26406  -3.8210089
# 2 -60.48000 -35.6500000
# 3 -69.61191 -13.1372421
# 4 -76.47461  -0.4788399
# 5 -65.59937 -37.9983271
# 6 -62.56333 -19.5500000

# %%
# %%R
# write.csv(dataset, file = "/tmp/my_data.csv")

# %%
# %%R
# dataset2 = read.csv('/griseoteste.csv')

# %%
# %%R
# head(dataset2)
# Out:
#   longitude    latitude
# 1 -70.26406  -3.8210089
# 2 -60.48000 -35.6500000
# 3 -69.61191 -13.1372421
# 4 -76.47461  -0.4788399
# 5 -65.59937 -37.9983271
# 6 -62.56333 -19.5500000
